# %%
import pickle
from pathlib import Path

data_path = Path('../outputs/outputs/trials_data/trials_dataset.pkl')
with open(data_path, 'rb') as f:
    data = pickle.load(f)

trials = data['all_trials']
print(f'Loaded {len(trials)} trials')
# Out:
# Loaded 256 trials

# %%
# Look at a single trial
i = 0
t = trials[i]
print(''.join(t['tokens']))
# Out:
# ## Machine Learning: Teaching Computers to Learn
#
# Imagine you're teaching a dog a trick. You don't tell the dog *exactly* how to sit, right? You show it, reward it when it gets close, and correct it when it's wrong. Eventually, the dog learns to sit on command.
#
# **Machine Learning is similar - it's about teaching computers to learn from data *without* explicitly programming them.**
#
# Here's a breakdown:
#
# * **Traditional Programming:** You tell the computer *exactly* what to do, step-by-step.  If X happens, do Y.
# * **Machine Learning:** You give the computer a lot of data and let it figure out the rules itself.
#
# **How does it work?**
#
# 1. **Data:** You feed the computer a bunch of examples. This is the "learning material." Think of it like showing the dog lots of examples of "sitting."
# 2. **

# %%
# Browse trials
for i in range(10):
    print(f'--- Trial {i} ---')
    print(''.join(trials[i]['tokens'])[:300])
    print()
# Out:
# --- Trial 0 ---
#
#
# ## Machine Learning: Teaching Computers to Learn
#
# Imagine you're teaching a dog a trick. You don't tell the dog *exactly* how to sit, right? You show it, reward it when it gets close, and correct it when it's wrong. Eventually, the dog learns to sit on command.
#
# **Machine Learning is similar - it'
#
# --- Trial 1 ---
#
#
# ## Machine Learning: Teaching Computers to Learn
#
# Imagine you're teaching a dog a trick. You don't tell the dog *exactly* how to do it, step-by-step. Instead, you show the dog what you want, reward good attempts, and correct mistakes. Over time, the dog learns to perform the trick without you need
#
# --- Trial 2 ---
#
#
# ## Machine Learning Explained Simply
#
# Imagine you're teaching a dog a trick. You don't tell the dog *exactly* how to do it, step-by-step. Instead, you show the dog what you want, reward it when it gets closer, and correct it when it's off.  Over time, the dog learns to do the trick without you exp
#
# ...
